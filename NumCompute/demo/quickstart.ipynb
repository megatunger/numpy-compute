# %% [markdown]
# # Getting Started

# %% [markdown]
# `NumCompute` is a python library dedicated for educational purpose. It's built upon pure python and numpy. To install this library, please follow `README.md`. For this quickstart, you can uncomment the code block below to prepare environment and install `NumCompute`.

# %%
# NOTE: Uncomment these lines to create and run this notebook in conda environment
# !conda create --name quickstart python=3.11 numpy
# !conda activate quickstart

# NOTE: If you haven't installed NumCompute, uncomment this line to install our module first 
# !pip install -e ..

# %% [markdown]
# Since `NumCompute` based on `numpy`, let's import `numpy` to create arrays and also do some setup for better display.

# %%
import numpy as np

# Set print options so it will be easier to follow printed arrays
np.set_printoptions(linewidth=200)

# %% [markdown]
# ## Loading data
#
# `NumCompute` allows loading data with its `io` module. You can load data from any csv file using `load_csv`, carefully adjusting its argument to match your specific data source.
#
# Below is an example where we load **Wine target dataset** from a csv file we provided, which contains 1599 samples with 12 real features. Since this file using semi-colon instead of commonly used colon, we have to specify delimiter as `";"`. The csv files are downloaded from [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/186/wine+target)

# %%
from numcompute.io import load_csv

wine = load_csv("../assets/winequality-red.csv", dtype=np.float32, delimiter=";")
wine.shape
# Out:
# (1599, 12)

# %% [markdown]
# Let's take a quick look at our data. As you can see, our data is loaded as a 2d-array `wine` with `dtype=float32`

# %%
wine
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]], dtype=float32)

# %% [markdown]
# ## Pre-processing and Statistics
#
# After loading data, you can exploring and processing your data using our `stats` and `preprocessing` modules.

# %%
from numcompute.stats import mean, median, std, min, max
from numcompute.preprocessing import MinMaxScaler

# %% [markdown]
# Let's inspecting our data. You can compute the statistics (mean, median, std) of any array using `numcompute.stats` module as demonstrated below. Note how we specify the `axis=1` to correctly compute the statistics specific to each features.

# %%
mean(wine, axis=1)
# Out:
# array([ 6.211983, 10.254567,  8.308251, ...,  8.373478,  8.767955,  7.707708], dtype=float32)

# %%
median(wine, axis=1)
# Out:
# array([2.705    , 2.9      , 2.78     , ..., 2.8600001, 2.7849998, 3.495    ], dtype=float32)

# %%
std(wine, axis=1)
# Out:
# array([ 9.127751 , 18.378534 , 14.469733 , ..., 12.29882  , 13.601475 , 11.5264015], dtype=float32)

# %% [markdown]
# Let's also check the min and max values for each features.

# %%
min(wine, axis=1), max(wine, axis=1)
# Out:
# (array([0.   , 0.   , 0.04 , ..., 0.076, 0.075, 0.067], dtype=float32),
#  array([34., 67., 54., ..., 40., 44., 42.], dtype=float32))

# %% [markdown]
# Now, let's try pre-processing our data using `MinMaxScaler`, which scale each features into range [0,1].

# %%
scaler = MinMaxScaler()
wine = scaler.fit_transform(wine)

# %% [markdown]
# Let's re-check the min and max of our data after processing

# %%
min(wine, axis=1), max(wine, axis=1)
# Out:
# (array([0.        , 0.        , 0.04      , ..., 0.09589041, 0.07534247, 0.0918197 ]),
#  array([0.60629909, 0.52054793, 0.5088094 , ..., 0.6       , 0.65354313, 0.6       ]))

# %% [markdown]
# ## Sorting, Searching and Ranking
#
# You can also sort and search any array with our `sort_search`, or rank the elements of an array with `rank`.

# %%
from numcompute.sort_search import multi_key_sort, topk
from numcompute.rank import rank, percentile

# %% [markdown]
# Let's try sorting our data with `multi_key_sort`, with which you can sort your your data using any features in any order. Note that here we are indexing `[:10]` to only show the first 10 records after sorted.

# %%
multi_key_sort(wine, columns=[3,2,1])[:10]
# Out:
# array([[0.30088497, 0.0410959 , 0.37      , 0.        , 0.06176961, 0.49295775, 0.3639576 , 0.        , 0.11811029, 0.06586825, 0.66153849, 0.6       ],
#        [0.30088497, 0.0410959 , 0.37      , 0.        , 0.06176961, 0.49295775, 0.3639576 , 0.        , 0.11811029, 0.06586825, 0.66153849, 0.6       ],
#        [0.23893808, 0.36301367, 0.        , 0.02054795, 0.0884808 , 0.1971831 , 0.05300353, 0.33259958, 0.51181101, 0.08383233, 0.2461539 , 0.8       ],
#        [0.07079648, 0.42465753, 0.        , 0.02054795, 0.04841402, 0.21126761, 0.14134276, 0.18428838, 1.        , 0.1556886 , 0.63076929, 0.6       ],
#        [0.03539824, 0.42465753, 0.        , 0.02054795, 0.04841402, 0.21126761, 0.14134276, 0.18428838, 1.        , 0.1556886 , 0.63076929, 0.6       ],
#        [0.1946903 , 0.47602738, 0.        , 0.02054795, 0.4257095 , 0.21126761, 0.08127208, 0.34067814, 0.45669277, 0.10778442, 0.2153847 , 0.        ],
#        [0.36283186, 0.47945204, 0.02      , 0.02054795, 0.09682805, 0.49295775, 0.14840989, 0.37665094, 0.36220469, 0.14970058, 0.2153847 , 0.4       ],
#        [0.07079648, 0.489726  , 0.08      , 0.02054795, 0.05676127, 0.16901408, 0.30742049, 0.17107209, 0.65354313, 0.31137725, 0.70769237, 0.8       ],
#        [0.23893808, 0.12671233, 0.38999999, 0.02054795, 0.07846411, 0.08450704, 0.01766784, 0.23788434, 0.43307075, 0.11377244, 0.47692314, 0.6       ],
#        [0.23893808, 0.12671233, 0.38999999, 0.02054795, 0.07846411, 0.08450704, 0.01766784, 0.23788434, 0.43307075, 0.11377244, 0.47692314, 0.6       ]])

# %% [markdown]
# To select the top-k values of any features, you can use `topk` function, which select the top-k values and also return the indices of the selected values.

# %%
topk(wine[:, 0], k=5)
# Out:
# (array([1.        , 0.97345139, 0.97345139, 0.9646018 , 0.9646018 ]),
#  array([652, 557, 442, 554, 555], dtype=int64))

# %% [markdown]
# Or you can find out the numerical ranks to values of a feature.

# %%
rank(wine[:, 0], method="ordinal")
# Out:
# array([531, 722, 723, ..., 121,  58,  71], dtype=int64)

# %% [markdown]
# Or you can compute the q-th percentile(s) of a feature

# %%
percentile(wine[:, 0], q=98)
# Out:
# 0.716814169001305

# %% [markdown]
# ## Optimization
#
# With `optim` module, you can easily compute gradients for iterative optimization algorithms.

# %%
from numcompute.optim import grad

# %% [markdown]
# Let's try defining some random parameters and compute its gradient with respect to a simple MSE loss.

# %%
from numcompute.metrics import mean_squared_error

# First we split our data into variables and target
variables = wine[:, :11]
target = wine[:, [11]]

# To compute the gradient of MSE loss with respecto parameters, we have to wrap
# every computation inside a single function
def forward(param):
    global variables, target
    batched_target = np.repeat(target, param.shape[0], axis=-1)
    pred = variables @ param.transpose()
    mse_loss = mean_squared_error(batched_target, pred, axis=0)
    return mse_loss

param = np.random.rand(11)
g = grad(forward, param)
print("gradient", g)
# Out:
# gradient [0.94771385 0.68545341 0.75101852 0.30994415 0.35762787 0.53048134 0.36358833 1.31130219 1.13248825 0.5364418  0.7390976 ]

# %% [markdown]
# Let's try updating our parameters using the computed gradients. Note how the updated parameters yield lower MSE loss, which demonstrate how this gradient can be used for optimization.

# %%
print("initial param", param)
print("loss before", forward(param[np.newaxis]))
updated_param = param - 0.1 * g
print("updated param", updated_param)
print("loss after", forward(updated_param[np.newaxis]))
# Out:
# initial param [0.93632904 0.98794561 0.17613562 0.75737999 0.88587032 0.2158464  0.37572441 0.60280491 0.63581167 0.51761132 0.67367693]
# loss before [1.7670826]
# updated param [0.84155765 0.91940027 0.10103377 0.72638557 0.85010753 0.16279826 0.33936557 0.47167469 0.52256285 0.46396714 0.59976717]
# loss after [1.1811703]

# %% [markdown]
# ## Benchmark
#
# Finally, let's run a benchmark to see how vectorization make everything faster.

# %%
from numcompute.benchmarking import main

main()
# Out:
# Start benchmark optim.py
# --------------------------------------------------
#
# Benchmark: grad
# loop: 0.000067 seconds
# vectorized: 0.000024 seconds
# vectorized is 2.76x compared to loop
# --------------------------------------------------
#
# Benchmark: jacobian
# loop: 0.000127 seconds
# vectorized: 0.000070 seconds
# vectorized is 1.83x compared to loop
# Start benchmark preprocessing.py
# --------------------------------------------------
#
# Benchmark: standard_scaler
# loop: 0.007364 seconds
# vectorized: 0.000114 seconds
# vectorized is 64.52x compared to loop
# --------------------------------------------------
#
# Benchmark: minmax_scaler
# loop: 0.005075 seconds
# vectorized: 0.000081 seconds
# vectorized is 62.78x compared to loop
# --------------------------------------------------
#
# Benchmark: one_hot_encoder
# loop: 0.003580 seconds
# vectorized: 0.000349 seconds
# vectorized is 10.27x compared to loop
# --------------------------------------------------
#
# Benchmark: simple_imputer
# loop: 0.003917 seconds
# vectorized: 0.000093 seconds
# vectorized is 42.04x compared to loop
# Start benchmark sort_search.py
# --------------------------------------------------
#
# Benchmark: stable_sort
# loop: 0.014396 seconds
# vectorized: 0.000031 seconds
# vectorized is 460.52x compared to loop
# --------------------------------------------------
#
# Benchmark: multi_key_sort
# loop: 0.037592 seconds
# vectorized: 0.000124 seconds
# vectorized is 302.04x compared to loop
# --------------------------------------------------
#
# Benchmark: topk
# loop: 0.000137 seconds
# vectorized: 0.000011 seconds
# vectorized is 12.68x compared to loop
# --------------------------------------------------
#
# Benchmark: binary_search
# loop: 0.000010 seconds
# vectorized: 0.000005 seconds
# vectorized is 1.99x compared to loop
# --------------------------------------------------
#
# Benchmark: quickselect
# loop: 0.000237 seconds
# vectorized: 0.000010 seconds
# vectorized is 24.14x compared to loop
# Start benchmark metrics.py
# --------------------------------------------------
#
# Benchmark: accuracy_score
# loop: 0.001726 seconds
# vectorized: 0.000034 seconds
# vectorized is 50.86x compared to loop
# --------------------------------------------------
#
# Benchmark: precision_score
# loop: 0.002996 seconds
# vectorized: 0.000051 seconds
# vectorized is 58.78x compared to loop
# --------------------------------------------------
#
# Benchmark: recall_score
# loop: 0.002829 seconds
# vectorized: 0.000048 seconds
# vectorized is 59.14x compared to loop
# --------------------------------------------------
#
# Benchmark: f1_score
# loop: 0.005621 seconds
# vectorized: 0.000097 seconds
# vectorized is 58.24x compared to loop
# --------------------------------------------------
#
# Benchmark: confusion_matrix
# loop: 0.002600 seconds
# vectorized: 0.000352 seconds
# vectorized is 7.39x compared to loop
# --------------------------------------------------
#
# Benchmark: mean_squared_error
# loop: 0.002309 seconds
# vectorized: 0.000025 seconds
# vectorized is 91.73x compared to loop
# Start benchmark stats.py
# --------------------------------------------------
#
# Benchmark: mean
# loop: 0.000557 seconds
# vectorized: 0.000011 seconds
# vectorized is 52.63x compared to loop
# --------------------------------------------------
#
# Benchmark: median
# loop: 0.002299 seconds
# vectorized: 0.000045 seconds
# vectorized is 51.60x compared to loop
# --------------------------------------------------
#
# Benchmark: std
# loop: 0.002565 seconds
# vectorized: 0.000031 seconds
# vectorized is 83.70x compared to loop
# --------------------------------------------------
#
# Benchmark: min
# loop: 0.000331 seconds
# vectorized: 0.000008 seconds
# vectorized is 38.98x compared to loop
# --------------------------------------------------
#
# Benchmark: max
# loop: 0.000343 seconds
# vectorized: 0.000008 seconds
# vectorized is 42.42x compared to loop
# Start benchmark rank.py
# --------------------------------------------------
#
# Benchmark: rank
# loop: 0.000262 seconds
# vectorized: 0.000048 seconds
# vectorized is 5.46x compared to loop
# --------------------------------------------------
#
# Benchmark: percentile
# loop: 0.000052 seconds
# vectorized: 0.000078 seconds
# vectorized is 0.66x compared to loop
# {'optim': {'grad': {'loop': 6.74309999885736e-05,
#    'vectorized': 2.4467999992339173e-05,
#    'speedup': 2.7558852382575596},
#   'jacobian': {'loop': 0.00012718600000880543,
#    'vectorized': 6.957699999475153e-05,
#    'speedup': 1.8279891346048203}},
#  'preprocessing': {'standard_scaler': {'loop': 0.007364412000006268,
#    'vectorized': 0.00011413399999582908,
#    'speedup': 64.52426095883254},
#   'minmax_scaler': {'loop': 0.005075297999992472,
#    'vectorized': 8.084299999609356e-05,
#    'speedup': 62.77968408195783},
#   'one_hot_encoder': {'loop': 0.0035799670000051264,
#    'vectorized': 0.00034850800000640447,
#    'speedup': 10.272266346652984},
#   'simple_imputer': {'loop': 0.003916854999988573,
#    'vectorized': 9.316300000136835e-05,
#    'speedup': 42.04303210428006}},
#  'sort_search': {'stable_sort': {'loop': 0.014395776000001206,
#    'vectorized': 3.1260000014299294e-05,
#    'speedup': 460.51746620013216},
#   'multi_key_sort': {'loop': 0.03759238599999662,
#    'vectorized': 0.00012446199998521478,
#    'speedup': 302.0390641678772},
#   'topk': {'loop': 0.00013687900000149966,
#    'vectorized': 1.079800000297837e-05,
#    'speedup': 12.67632894644794},
#   'binary_search': {'loop': 1.0261999996146187e-05,
#    'vectorized': 5.163000005268259e-06,
#    'speedup': 1.9876041033652865},
#   'quickselect': {'loop': 0.00023745799999232985,
#    'vectorized': 9.83500000074855e-06,
#    'speedup': 24.14417895010236}},
#  'metrics': {'accuracy_score': {'loop': 0.0017255959999965852,
#    'vectorized': 3.392900000108057e-05,
#    'speedup': 50.85902914738508},
#   'precision_score': {'loop': 0.0029956270000002405,
#    'vectorized': 5.0960999997187175e-05,
#    'speedup': 58.78273582083527},
#   'recall_score': {'loop': 0.002829269000012573,
#    'vectorized': 4.7837999991315885e-05,
#    'speedup': 59.142710826668655},
#   'f1_score': {'loop': 0.00562068499999441,
#    'vectorized': 9.650199999668984e-05,
#    'speedup': 58.24423328207921},
#   'confusion_matrix': {'loop': 0.0025996970000051077,
#    'vectorized': 0.0003518409999924188,
#    'speedup': 7.388840413883328},
#   'mean_squared_error': {'loop': 0.0023094789999959175,
#    'vectorized': 2.5175999999191843e-05,
#    'speedup': 91.73335716833701}},
#  'stats': {'mean': {'loop': 0.0005565199999909965,
#    'vectorized': 1.0574999996606494e-05,
#    'speedup': 52.62600474416862},
#   'median': {'loop': 0.002298695999998017,
#    'vectorized': 4.455199999938486e-05,
#    'speedup': 51.59579816910028},
#   'std': {'loop': 0.002564683000000514,
#    'vectorized': 3.064200000153505e-05,
#    'speedup': 83.69828992467961},
#   'min': {'loop': 0.00033050399999410727,
#    'vectorized': 8.478999989165459e-06,
#    'speedup': 38.97912494591676},
#   'max': {'loop': 0.0003430549999939103,
#    'vectorized': 8.087000005616573e-06,
#    'speedup': 42.42055147219639}},
#  'rank': {'rank': {'loop': 0.00026225699999486094,
#    'vectorized': 4.800799999429728e-05,
#    'speedup': 5.462777037702334},
#   'percentile': {'loop': 5.157499999768334e-05,
#    'vectorized': 7.814399999915622e-05,
#    'speedup': 0.6599994881019685}}}
